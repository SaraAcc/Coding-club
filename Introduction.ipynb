# %% [markdown]
# # Atelier d'introduction à Jupyter Notebook!
#
# Jupyter lab est un environnement de programmation interactif qui permet de faire de la programmation en Python, R, Julia, etc.
# Aujourd'hui, nous allons nous concentrer sur Python.
# On va apprendre à utiliser Jupyter notebook car c'est un outil qui est très utilisé pour les visualisations. Il est très probable que certains de tes cours d'informatique soient sur Jupyter Notebook lorsque tu iras en université.
# Il permet au professeur d'expliquer le cours et de permettre aux étudiants de changer le code s'ils en ont envie.
#
#
# <center><span style="font-size:40px;color:brown"  > Let's go ! </span></center>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1. Les cellules
#
# Jupyter est un environnement de programmation qui permet de faire de la programmation en Python. Il est composé de cellules qui peuvent être de deux types: des cellules de **texte** et des cellules de **code**.
# Les cellules de texte sont utilisées pour écrire du texte et les cellules de code sont utilisées pour écrire du code.
# Pour exécuter une cellule, il suffit de cliquer sur le bouton "Exécuter" dans la barre d'outils.

# %% [markdown]
# Tout d'abord, familiarisons nous avec la barre d'outils.
#
# ![image.png](attachment:b43c477b-5e93-4c38-8df0-047f955961fd.png)

# %% [markdown]
# Maintenant, voyons voir de quoi se compose une cellule !
#
# ![image.png](attachment:28401b69-342a-4e81-b8a4-51d03a8764f8.png)

# %% [markdown]
# Lorsque tu vas rajouter une cellule, cette dernière va être une cellule de **code** par défaut.
# Pour pouvoir la changer en cellule de texte, séléctionne là, appuie sur le type de la cellule dans la barre en haut
# ![image.png](attachment:ab02fc12-4486-4e7b-8c83-b654e381be7b.png)
# et choisis le type qui te convient.
# - Markdown est le type d'une cellule de texte
# - Code est le type d'une cellule de code

# %% [markdown]
# Si tu veux modifier une cellule de texte déjà existante, tu dois double cliquer n'importe où dans la cellule.
# Quand tu auras fini tes modifications, n'oublie pas d'exécuter la cellule en appuyant sur le bouton ![image.png](attachment:560465b6-89d5-4ede-9a9b-6e07c22f0ae2.png)

# %% [markdown]
# **Faisons un petit test:**
# Double-clique sur cette cellule pour modifier le texte suivant: **Je m'appelle [ton prénom] et j'ai [ton âge] ans**.

# %% [markdown]
# #### a) Les cellules de texte

# %% [markdown]
# Pour cette partie de l'atelier, tu auras besoin de connaître les couleurs en anglais.
# Voici une traduction des couleurs dont tu pourrais avoir besoin:
# - <span style="color:red"> rouge: red </span>
# - <span style="color:blue"> bleu: blue </span>
# - <span style="color:green"> vert: green </span>
# - <span style="color:yellow"> jaune: yellow </span>
# - <span style="color:orange"> orange: orange </span>
# - <span style="color:purple"> violet: purple </span>
# - <span style="color:brown"> marron: brown </span>
# - <span style="color:pink"> rose: pink </span>
# - <span style="color:black"> noir: black </span>

# %% [markdown]
# <span style="font-size:30px;color:brown"  > Comment changer la couleur d'un texte?  </span>
#
# Pour changer la couleur d'un texte, il suffit de mettre le texte entre les balises `<span style="color:"une couleur en anglais"">` et `</span>`.
# Voici quelques exemples: **(Double-clique sur la cellule pour voir comment le texte a été écrit.)**
# - <span style="color:blue"> Vive la programmation ! </span>
# - <span style="color:red"> Vive la programmation ! </span>
# - <span style="color:green"> Vive la programmation ! </span>
# - <span style="color:pink"> Vive la programmation ! </span>
#
# A présent, à toi de jouer!
#
# **Ecris ton plat préféré dans la couleur de ton choix :**
#
# Ton plat préféré :

# %% [markdown]
# <span style="font-size:30px;color:brown"  > Comment surligner un texte?  </span>
#
# Pour surligner un texte, il suffit de mettre le texte entre les balises `<span style="background-color:"une couleur en anglais"">` et `</span>`.
# Voici quelques exemples: **(Double-clique sur la cellule pour voir comment le texte a été écrit.)**
# - <span style="background-color:yellow"> Vive la programmation ! </span>
# - <span style="background-color:red"> Vive la programmation ! </span>
# - <span style="background-color:green"> Vive la programmation ! </span>
# - <span style="background-color:blue"> Vive la programmation ! </span>
#
# A présent, à toi de jouer!
#
# **Ecris ton animal préféré en le surlignant avec la couleur de ton choix :**
#
# Ton animal préféré :

# %% [markdown]
# <span style="font-size:30px;color:brown"  > Comment changer la taille d'un texte?  </span>
#
# Pour changer la taille d'un texte, il suffit de mettre le texte entre les balises `<span style="font-size:"valeur"px">` et `</span>`.
# font-size en anglais veut dire taille de la police. Donc plus la valeur de font-size est grande, plus ton texte sera gros !
# Voici quelques exemples: **(Double-clique sur la cellule pour voir comment le texte a été écrit.)**
# - <span style="font-size:10px"> Vive la programmation ! </span>
# - <span style="font-size:20px"> Vive la programmation ! </span>
# - <span style="font-size:30px"> Vive la programmation ! </span>
# - <span style="font-size:40px"> Vive la programmation ! </span>
#
# A présent, à toi de jouer!
#
# **Ecris ton sport préféré dans la taille de ton choix :**
#
# Ton sport préféré :

# %% [markdown]
# <span style="font-size:30px;color:brown"  > Comment combiner plusieurs styles?  </span>
#
# Pour combiner plusieurs styles, il suffit d'écrire la même chose qu'avant mais de rajouter un `;` entre chaque style.
# Voici quelques exemples: **(Double-clique sur la cellule pour voir comment le texte a été écrit.)**
# - <span style="color:blue;font-size:20px"> Vive la programmation ! </span>
# - <span style="color:red;font-size:30px"> Vive la programmation ! </span>
# - <span style="color:green;font-size:40px"> Vive la programmation ! </span>
# - <span style="color:orange;font-size:50px"> Vive la programmation ! </span>
#
# A présent, à toi de jouer!
#
# **Ecris ton film préféré en le surlignant avec la couleur de ton choix et en le mettant dans la taille de ton choix :**
#
# Ton film préféré :

# %% [markdown]
# <center><span style="font-size:30px;color:brown"  > Bravo à toi !  </span></center>
#
# Tu as appris à mettre du texte en couleur, à le surligner et à changer sa taille !
# C'est l'une des fonctionnalités de Jupyter notebook qui est très utile pour faire des présentations.
# Maintenant, passons à l'autre fonctionnalité de Jupyter notebook: les cellules de code.

# %% [markdown]
# #### b) Les cellules de code

# %% [markdown]
# Comme dit précédemment, nous allons faire de la programmation en Python.
# Python est un langage de programmation qui est très utilisé dans le domaine de la science des données.
# Pour commencer, nous allons apprendre les notions de base en Python.
# Les cellules dans Jupyter Notebook affichent le résultat de la dernière ligne de code.

# %%
# Ceci est une cellule de code
# Le texte écrit après le # est un commentaire, il n'est pas lu par l'ordinateur comme du code
# Pour exécuter le code de cette cellule, clique sur le bouton Exécuter dans la barre d'outils

# Nous allons afficher un message à l'écran, en dessous de cette cellule
print("Bonjour !")

############################################################
#TODO: Ecris un message que tu aimerais afficher à l'écran #

############################################################
# Out:
# Bonjour !

# %%
# Nous allons, à présent, déclarer des variables. Une variable est un espace mémoire dans lequel on peut stocker une valeur. 
# On peut stocker des nombres, des textes, des listes, etc.

# Pour déclarer une variable, on écrit son nom, puis on utilise le signe =
# on peut ensuite utiliser la variable dans le code


a = "Meringue"
print(a)

############################################################
#TODO: A présent, modifie la valeur de a et affiche la     #
#Qu'est ce que tu observes ?                               #

############################################################
# Out:
# Meringue

# %%
# On peut aussi déclarer plusieurs variables en même temps

oranges = 5
pommes = 10
bananes = 3

############################################################
#TODO: A présent, calcule et affiche le nombre de fruits total    
#Indice: faire a + b équivaut à additionner les valeurs de ces variables


############################################################

# %% [markdown]
# A présent, imagine que tu es une professeure. Tu as besoin de faire la présentation du cours à tes élèves. Il faut que ton cours ait une présentation et du code à l'intérieur. Comme dans l'exemple au dessus, on t'a demandé de calculer le nombre de fruits total. Sois créative et fais la même chose.

# %% [markdown]
# 1) La première étape à suivre est de créer les cellules de texte et de code.
# 2) Ensuite, écris ce que tu as envie d'apprendre à tes élèves dans ces cellules.
# 3) Tu peux ensuite rendre ton texte plus joli grâce à ce que tu as appris plus haut.

# %% [markdown]
# *Double-clique ici pour commencer à écrire ton cours*

# %%
# Ecris ton code ici
